# %%
# importing csv module 
import csv 
import scipy.stats
from datetime import datetime
from datetime import timedelta
import calendar
from dateutil.relativedelta import *

# initializing the titles and rows list 
prev = [] 
Price_close = [] 
Price_open = [] 
Price_avg = []
Trend = [] 
Trend_Percent = []
import codecs
filename = 'C:/Users/sachi/OneDrive/Documents/Assignments/Sem3/COMP541/Project/Data/INTEGRATED_DATA_CLEAN.csv'
import pandas as pd
df1 = pd.read_csv(filename)
print(df1)
# Out:
#            Date Symbol     Open     High      Low    Close        Volume  \
# 0     4/28/2013    BTC   135.30   135.98   132.10   134.21           NaN
# 1     4/29/2013    BTC   134.44   147.49   134.00   144.54           NaN
# 2     4/30/2013    BTC   144.00   146.93   134.05   139.00           NaN
# 3      5/1/2013    BTC   139.00   139.89   107.72   116.99           NaN
# 4      5/2/2013    BTC   116.38   125.60    92.28   105.21           NaN
# 5      5/3/2013    BTC   106.25   108.13    79.10    97.75           NaN
# 6      5/4/2013    BTC    98.10   115.00    92.50   112.50           NaN
# 7      5/5/2013    BTC   112.90   118.80   107.14   115.91           NaN
# 8      5/6/2013    BTC   115.98   124.66   106.64   112.30           NaN
# 9      5/7/2013    BTC   112.25   113.44    97.70   111.50           NaN
# 10     5/8/2013    BTC   109.60   115.78   109.60   113.57           NaN
# 11     5/9/2013    BTC   113.20   113.46   109.26   112.67           NaN
# ...

# %%
print(df1)
# Out:
#            Date Symbol     Open     High      Low    Close        Volume  \
# 0     4/28/2013    BTC   135.30   135.98   132.10   134.21           NaN
# 1     4/29/2013    BTC   134.44   147.49   134.00   144.54           NaN
# 2     4/30/2013    BTC   144.00   146.93   134.05   139.00           NaN
# 3      5/1/2013    BTC   139.00   139.89   107.72   116.99           NaN
# 4      5/2/2013    BTC   116.38   125.60    92.28   105.21           NaN
# 5      5/3/2013    BTC   106.25   108.13    79.10    97.75           NaN
# 6      5/4/2013    BTC    98.10   115.00    92.50   112.50           NaN
# 7      5/5/2013    BTC   112.90   118.80   107.14   115.91           NaN
# 8      5/6/2013    BTC   115.98   124.66   106.64   112.30           NaN
# 9      5/7/2013    BTC   112.25   113.44    97.70   111.50           NaN
# 10     5/8/2013    BTC   109.60   115.78   109.60   113.57           NaN
# 11     5/9/2013    BTC   113.20   113.46   109.26   112.67           NaN
# ...

# %%
import plotly.plotly as py
import plotly.graph_objs as go
import plotly.figure_factory as FF

import numpy as np
import pandas as pd

# %%
import plotly.plotly as py
import plotly.figure_factory as ff

import numpy as np

hist_data = [[1,2,2,2,3,3,3,2,2,2,1,1]]
group_labels = ['distplot']

fig = ff.create_distplot(hist_data, group_labels)
py.iplot(fig, filename='Basic Distplot')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~sach1990/24.embed" height="525px" width="100%"></iframe>

# %%
import plotly

plotly.tools.set_credentials_file(username='sach1990', api_key='0lbBY8ZsUHSOfzW9FO5y')
plotly.offline.init_notebook_mode(connected=True)
import plotly.plotly as py
import plotly.graph_objs as go
import plotly.figure_factory as FF

import numpy as np
import pandas as pd
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
df = pd.read_csv(filename)

df_external_source = FF.create_table(df.head())

# %%
import plotly.plotly as py
import plotly.figure_factory as ff

import numpy as np

hist_data = [df1['Close']]
group_labels = ['distplot']

fig = ff.create_distplot(hist_data, group_labels)
py.iplot(fig, filename='Basic Distplot')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~sach1990/24.embed" height="525px" width="100%"></iframe>

# %%
py.iplot(df_external_source, filename='df-external-source-table')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~sach1990/26.embed" height="230px" width="100%"></iframe>

# %%
traceClose = go.Scatter(x = df['Date'], y = df['Close'],
                  name='Closing Price (in USD)')
traceOpen = go.Scatter(x = df['Date'], y = df['Open'],
                  name='Opening Price (in USD)')
traceHigh = go.Scatter(x = df['Date'], y = df['High'],
                  name='Highest Price (in USD)')
traceLow = go.Scatter(x = df['Date'], y = df['Low'],
                  name='Lowest Price (in USD)')
layout = go.Layout(title='Bitcoin prices over time 2013-2018',
                   plot_bgcolor='rgb(230, 230,230)', 
                   showlegend=True)
fig = go.Figure(data=[traceClose,traceOpen,traceHigh,traceLow], layout=layout)

py.iplot(fig, filename='bitcoin-prices')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~sach1990/22.embed" height="525px" width="100%"></iframe>

# %%
from sklearn import preprocessing

# %%
from sklearn import preprocessing
min_max_scaler = preprocessing.MinMaxScaler()

# %%
x = df[['Close']].values.astype(float)

# %%
x_scaled = min_max_scaler.fit_transform(x)

# %%
df_normalized = pd.DataFrame(x_scaled)

# %%
df['Close'] = df_normalized[0]

# %%
df
# Out:
#            Date Symbol     Open     High      Low     Close        Volume  \
# 0     4/28/2013    BTC   135.30   135.98   132.10  0.003386           NaN
# 1     4/29/2013    BTC   134.44   147.49   134.00  0.003917           NaN
# 2     4/30/2013    BTC   144.00   146.93   134.05  0.003632           NaN
# 3      5/1/2013    BTC   139.00   139.89   107.72  0.002499           NaN
# 4      5/2/2013    BTC   116.38   125.60    92.28  0.001893           NaN
# 5      5/3/2013    BTC   106.25   108.13    79.10  0.001509           NaN
# 6      5/4/2013    BTC    98.10   115.00    92.50  0.002268           NaN
# 7      5/5/2013    BTC   112.90   118.80   107.14  0.002444           NaN
# 8      5/6/2013    BTC   115.98   124.66   106.64  0.002258           NaN
# 9      5/7/2013    BTC   112.25   113.44    97.70  0.002217           NaN
# 10     5/8/2013    BTC   109.60   115.78   109.60  0.002323           NaN
# 11     5/9/2013    BTC   113.20   113.46   109.26  0.002277           NaN
# ...

# %%
traceClose = go.Scatter(x = df['Date'], y = df['Close'],
                  name='Closing Price (in USD)')
traceOpen = go.Scatter(x = df['Date'], y = df['Open'],
                  name='Opening Price (in USD)')
traceHigh = go.Scatter(x = df['Date'], y = df['High'],
                  name='Highest Price (in USD)')
traceLow = go.Scatter(x = df['Date'], y = df['Low'],
                  name='Lowest Price (in USD)')
layout = go.Layout(title='Bitcoin prices over time 2013-2018',
                   plot_bgcolor='rgb(230, 230,230)', 
                   showlegend=True)
fig = go.Figure(data=[traceClose,traceOpen,traceHigh,traceLow], layout=layout)

py.iplot(fig, filename='bitcoin-prices')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~sach1990/22.embed" height="525px" width="100%"></iframe>

# %%
df.to_csv('NormalizedBitcoinPricesIntegratedData.csv')

# %%
x = df[['TotalSearch']].values.astype(float)
x_scaled = min_max_scaler.fit_transform(x)
df_normalized = pd.DataFrame(x_scaled)
df['TotalSearch'] = df_normalized[0]
df
# Out:
#            Date Symbol     Open     High      Low     Close        Volume  \
# 0     4/28/2013    BTC   135.30   135.98   132.10  0.003386           NaN
# 1     4/29/2013    BTC   134.44   147.49   134.00  0.003917           NaN
# 2     4/30/2013    BTC   144.00   146.93   134.05  0.003632           NaN
# 3      5/1/2013    BTC   139.00   139.89   107.72  0.002499           NaN
# 4      5/2/2013    BTC   116.38   125.60    92.28  0.001893           NaN
# 5      5/3/2013    BTC   106.25   108.13    79.10  0.001509           NaN
# 6      5/4/2013    BTC    98.10   115.00    92.50  0.002268           NaN
# 7      5/5/2013    BTC   112.90   118.80   107.14  0.002444           NaN
# 8      5/6/2013    BTC   115.98   124.66   106.64  0.002258           NaN
# 9      5/7/2013    BTC   112.25   113.44    97.70  0.002217           NaN
# 10     5/8/2013    BTC   109.60   115.78   109.60  0.002323           NaN
# 11     5/9/2013    BTC   113.20   113.46   109.26  0.002277           NaN
# ...

# %%
df.to_csv('NormalizedIntegratedData.csv')

# %%
# timestamp conversion
import time
readable = time.ctime(1538405266)
readable
# Out:
# 'Mon Oct  1 07:47:46 2018'

# %%
#Corelation

import matplotlib
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# Read file into a Pandas dataframe
def correlation_matrix(df):
    from matplotlib import pyplot as plt
    from matplotlib import cm as cm

    fig = plt.figure()
    ax1 = fig.add_subplot(111)
    cmap = cm.get_cmap('jet', 30)
    cax = ax1.imshow(df.corr(), interpolation="nearest", cmap=cmap)
    ax1.grid(True)
    plt.title('Cryptocurrentcy GTrend Feature Correlation')
    labels=['Date','Symbol','Open','High','Low','Close','Volume','MarketCap','PercentSearch','TotalSearch']
    ax1.set_xticklabels(labels,fontsize=3)
    ax1.set_yticklabels(labels,fontsize=3)
    # Add colorbar, make sure to specify tick locations to match desired ticklabels
    fig.colorbar(cax, ticks=[.75,.8,.85,.90,.95,1])
    plt.show()

correlation_matrix(df)

# %%
df = pd.read_csv('NormalizedIntegratedData.csv')
x = df[['Close']].values.astype(float)
x_scaled = min_max_scaler.fit_transform(x)
df_normalized = pd.DataFrame(x_scaled)
df['Close'] = df_normalized[0]


x = df[['Open']].values.astype(float)
x_scaled = min_max_scaler.fit_transform(x)
df_normalized = pd.DataFrame(x_scaled)
df['Open'] = df_normalized[0]

x = df[['High']].values.astype(float)
x_scaled = min_max_scaler.fit_transform(x)
df_normalized = pd.DataFrame(x_scaled)
df['High'] = df_normalized[0]


x = df[['Low']].values.astype(float)
x_scaled = min_max_scaler.fit_transform(x)
df_normalized = pd.DataFrame(x_scaled)
df['Low'] = df_normalized[0]
df.describe()
df.to_csv('CompleteNormalized.csv')

# %%
x = df['Date']
x
# Out:
# 0       4/28/2013
# 1       4/29/2013
# 2       4/30/2013
# 3        5/1/2013
# 4        5/2/2013
# 5        5/3/2013
# 6        5/4/2013
# 7        5/5/2013
# 8        5/6/2013
# 9        5/7/2013
# 10       5/8/2013
# 11       5/9/2013
# 12      5/10/2013
# 13      5/11/2013
# 14      5/12/2013
# 15      5/13/2013
# 16      5/14/2013
# 17      5/15/2013
# 18      5/16/2013
# 19      5/17/2013
# 20      5/18/2013
# 21      5/19/2013
# 22      5/20/2013
# 23      5/21/2013
# 24      5/22/2013
# 25      5/23/2013
# 26      5/24/2013
# 27      5/25/2013
# 28      5/26/2013
# 29      5/27/2013
#           ...
# 1832     5/4/2018
# 1833     5/5/2018
# 1834     5/6/2018
# 1835     5/7/2018
# 1836     5/8/2018
# 1837     5/9/2018
# 1838    5/10/2018
# 1839    5/11/2018
# 1840    5/12/2018
# 1841    5/13/2018
# 1842    5/14/2018
# 1843    5/15/2018
# 1844    5/16/2018
# 1845    5/17/2018
# 1846    5/18/2018
# 1847    5/19/2018
# 1848    5/20/2018
# 1849    5/21/2018
# 1850    5/22/2018
# ...

# %%
import plotly.plotly as py
import plotly.graph_objs as go

# Create random data with numpy
import numpy as np

N = 1000
df = pd.read_csv('DayAvgSearchNotNormalized.csv')
random_x = df['Close']
random_y = df['Avg_5WeekSearch']

# Create a trace
trace = go.Scatter(
    x = random_x,
    y = random_y,
    mode = 'markers'
)

data = [trace]

# Plot and embed in ipython notebook!
py.iplot(data, filename='basic-scatter')

# or plot with: plot_url = py.plot(data, filename='basic-line')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~sach1990/16.embed" height="525px" width="100%"></iframe>

# %%
df = pd.read_csv('DayAvgSearchNotNormalized.csv')
decimals = pd.Series([0, 0, 0, 0, 0, 0], index=['Open','High','Low','Close','TotalSearch','Avg_5WeekSearch'])
df.round(decimals)
df.head()
df.to_csv('RoundedDayAvgSearchNotNormalized.csv')

# %%
import plotly.plotly as py
import plotly.graph_objs as go

# Create random data with numpy
import numpy as np

N = 1000
df = pd.read_csv('DayAvgSearchNotNormalizedReduced.csv')
random_x = df['Close']
random_y = df['Avg_5WeekSearch']

# Create a trace
trace = go.Scatter(
    x = random_x,
    y = random_y,
    mode = 'markers'
)

data = [trace]

# Plot and embed in ipython notebook!
py.iplot(data, filename='basic-scatter')

# or plot with: plot_url = py.plot(data, filename='basic-line')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~sach1990/16.embed" height="525px" width="100%"></iframe>

# %%
df = pd.read_csv('RoundedDayAvgSearchNotNormalized.csv')
x = df[['Close']].values.astype(float)
x_scaled = min_max_scaler.fit_transform(x)
df_normalized = pd.DataFrame(x_scaled)
df['Close'] = df_normalized[0]


x = df[['Open']].values.astype(float)
x_scaled = min_max_scaler.fit_transform(x)
df_normalized = pd.DataFrame(x_scaled)
df['Open'] = df_normalized[0]

x = df[['High']].values.astype(float)
x_scaled = min_max_scaler.fit_transform(x)
df_normalized = pd.DataFrame(x_scaled)
df['High'] = df_normalized[0]


x = df[['Low']].values.astype(float)
x_scaled = min_max_scaler.fit_transform(x)
df_normalized = pd.DataFrame(x_scaled)
df['Low'] = df_normalized[0]




x = df[['TotalSearch']].values.astype(float)
x_scaled = min_max_scaler.fit_transform(x)
df_normalized = pd.DataFrame(x_scaled)
df['TotalSearch'] = df_normalized[0]

x = df[['Avg_5WeekSearch']].values.astype(float)
x_scaled = min_max_scaler.fit_transform(x)
df_normalized = pd.DataFrame(x_scaled)
df['Avg_5WeekSearch'] = df_normalized[0]

df.describe()
df.to_csv('FinalNormalized.csv')

# %%
import plotly.plotly as py
import plotly.graph_objs as go

# Create random data with numpy
import numpy as np

N = 1000
df = pd.read_csv('FinalNormalized.csv')
random_x = df['Close']
random_y = df['Avg_5WeekSearch']

# Create a trace
trace = go.Scatter(
    x = random_x,
    y = random_y,
    mode = 'markers'
)

data = [trace]

# Plot and embed in ipython notebook!
py.iplot(data, filename='basic-scatter')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~sach1990/16.embed" height="525px" width="100%"></iframe>

# %%
df = pd.read_csv('DayAvgSearchNotNormalized.csv')
x = df[['Close']].values.astype(float)
x_scaled = min_max_scaler.fit_transform(x)
df_normalized = pd.DataFrame(x_scaled)
df['Close'] = df_normalized[0]


x = df[['Open']].values.astype(float)
x_scaled = min_max_scaler.fit_transform(x)
df_normalized = pd.DataFrame(x_scaled)
df['Open'] = df_normalized[0]

x = df[['High']].values.astype(float)
x_scaled = min_max_scaler.fit_transform(x)
df_normalized = pd.DataFrame(x_scaled)
df['High'] = df_normalized[0]


x = df[['Low']].values.astype(float)
x_scaled = min_max_scaler.fit_transform(x)
df_normalized = pd.DataFrame(x_scaled)
df['Low'] = df_normalized[0]




x = df[['TotalSearch']].values.astype(float)
x_scaled = min_max_scaler.fit_transform(x)
df_normalized = pd.DataFrame(x_scaled)
df['TotalSearch'] = df_normalized[0]

x = df[['Avg_5WeekSearch']].values.astype(float)
x_scaled = min_max_scaler.fit_transform(x)
df_normalized = pd.DataFrame(x_scaled)
df['Avg_5WeekSearch'] = df_normalized[0]

df.describe()
df.to_csv('FinalUnRoundedNormalized.csv')

# %%
import plotly.plotly as py
import plotly.tools as tls
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv('DayAvgSearchNotNormalizedReduced.csv')
df = df.round({'Avg_5WeekSearch': -1, 'Close': 1})

# %%
random_x = df['Close']
random_y = df['Avg_5WeekSearch']

# Create a trace
trace = go.Scatter(
    x = random_x,
    y = random_y,
    mode = 'markers'
)

data = [trace]

# Plot and embed in ipython notebook!
py.iplot(data, filename='basic-scatter')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~sach1990/16.embed" height="525px" width="100%"></iframe>

# %%
gaussian_numbers = np.log(df['Close'])
plt.hist(gaussian_numbers)
plt.title("Bitcoin Price Histogram")
plt.xlabel("Value")
plt.ylabel("Frequency")

fig = plt.gcf()
plotly_fig = tls.mpl_to_plotly( fig )
py.iplot(plotly_fig, filename='mpl-basic-histogram')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~sach1990/12.embed" height="288px" width="432px"></iframe>

# %%
import plotly.plotly as py
import plotly.figure_factory as ff

import numpy as np

x1 = np.log(df['Close'])
 
hist_data = [x1]

group_labels = ['Group 1']

colors = ['#3A4750']

# Create distplot with curve_type set to 'normal'
fig = ff.create_distplot(hist_data, group_labels, bin_size=1, curve_type='normal', colors=colors)

# Add title
fig['layout'].update(title='Distplot with Normal Distribution')

# Plot!
py.iplot(fig, filename='Distplot with Normal Curve')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~sach1990/20.embed" height="525px" width="100%"></iframe>

# %%
gaussian_numbers = df['Avg_5WeekSearch']
plt.hist(gaussian_numbers)
plt.title("Google Search Histogram")
plt.xlabel("Value")
plt.ylabel("Frequency")

fig = plt.gcf()
plotly_fig = tls.mpl_to_plotly( fig )
py.iplot(plotly_fig, filename='mpl-basic-histogram')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~sach1990/12.embed" height="288px" width="432px"></iframe>

# %%
df['Avg_5WeekSearch'] = np.log(df['Avg_5WeekSearch'])

gaussian_numbers = df['Avg_5WeekSearch']
plt.hist(gaussian_numbers)
plt.title("Google Search Histogram")
plt.xlabel("Value")
plt.ylabel("Frequency")

fig = plt.gcf()
plotly_fig = tls.mpl_to_plotly( fig )
py.iplot(plotly_fig, filename='mpl-basic-histogram')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~sach1990/12.embed" height="288px" width="432px"></iframe>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# %matplotlib inline
df.head()
# Out:
#    Unnamed: 0       Date     Open     High      Low   Close   TotalSearch  \
# 0        1498   7/9/2017  2572.61  2635.49  2517.59  2518.4   96867.46988
# 1        1499  7/10/2017  2525.25  2537.16  2321.13  2372.6  111325.30120
# 2        1500  7/11/2017  2385.89  2413.47  2296.81  2337.8  122891.56630
# 3        1501  7/12/2017  2332.77  2423.71  2275.14  2398.8  114216.86750
# 4        1502  7/13/2017  2402.70  2425.22  2340.83  2357.9  108433.73490
#
#    Avg_5WeekSearch
# 0        11.795319
# 1        11.789344
# 2        11.783563
# 3        11.770123
# 4        11.757517

# %%
data = df.iloc[:, [7,5]]

data.head()
# Out:
#    Avg_5WeekSearch   Close
# 0        11.795319  2518.4
# 1        11.789344  2372.6
# 2        11.783563  2337.8
# 3        11.770123  2398.8
# 4        11.757517  2357.9

# %%
import numpy as np
import pandas
from pandas import DataFrame, Series
from sklearn.model_selection import train_test_split
X = data[['Close']].values.astype(float)
Y = data[['Avg_5WeekSearch']].values.astype(float)
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2)
import statsmodels.formula.api as sm
from sklearn.linear_model import LinearRegression
import scipy, scipy.stats
result = sm.OLS( Y_train, X_train ).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.850
# Model:                            OLS   Adj. R-squared:                  0.849
# Method:                 Least Squares   F-statistic:                     1485.
# Date:                Fri, 14 Dec 2018   Prob (F-statistic):          6.17e-110
# Time:                        16:41:32   Log-Likelihood:                -790.52
# No. Observations:                 263   AIC:                             1583.
# Df Residuals:                     262   BIC:                             1587.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.0013   3.41e-05     38.533      0.000       0.001       0.001
# ...

# %%
from sklearn import preprocessing
min_max_scaler = preprocessing.MinMaxScaler()

x = data[['Close']].values.astype(float)
x_scaled = min_max_scaler.fit_transform(x)
data_normalized = pd.DataFrame(x_scaled)
data['Close'] = data_normalized[0]

x = data[['Avg_5WeekSearch']].values.astype(float)
x_scaled = min_max_scaler.fit_transform(x)
data_normalized = pd.DataFrame(x_scaled)
data['Avg_5WeekSearch'] = data_normalized[0]

X = data.iloc[:, :-1]
Y = data.iloc[:, 1]





data.head()
# Out:
#    Avg_5WeekSearch     Close
# 0         0.057019  0.033505
# 1         0.054489  0.025205
# 2         0.052041  0.023225
# 3         0.046350  0.026697
# 4         0.041013  0.024369

# %%
data.corr()
# Out:
#                  Avg_5WeekSearch     Close
# Avg_5WeekSearch         1.000000  0.874036
# Close                   0.874036  1.000000

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2)
from sklearn.linear_model import LinearRegression
regressor = LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=True)
regressor.fit(X_train, Y_train)
from sklearn.metrics import r2_score
Y_pred = regressor.predict(X_test)
r2_score(Y_test, Y_pred)
# Out:
# 0.7682233069925621

# %%
print(regressor.coef_)
# Out:
# [0.66774747]

# %%
print(regressor.intercept_)
# Out:
# 0.07789535016647997

# %%
from sklearn.metrics import r2_score
r2_score(Y_test, Y_pred)
# Out:
# 0.7682233069925621

# %%
from sklearn.metrics import r2_score
r2_score(Y_test, Y_pred)
# Out:
# 0.7682233069925621

# %%
import plotly.plotly as py
import plotly.tools as tls

import matplotlib.pyplot as plt
import numpy as np

gaussian_numbers = Y_test
plt.hist(gaussian_numbers)
plt.title("Gaussian Histogram")
plt.xlabel("Value")
plt.ylabel("Frequency")

fig = plt.gcf()
plotly_fig = tls.mpl_to_plotly( fig )
py.iplot(plotly_fig, filename='mpl-basic-histogram')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~sach1990/12.embed" height="288px" width="432px"></iframe>

# %%
import pandas as pd

columns_new = ['Y_test']
df_ytest = pd.DataFrame(Y_test, columns=columns_new)

columns_new = ['X_test']
df_xtest = pd.DataFrame(X_test, columns=columns_new)

columns_new = ['Y_pred']
df_ypred = pd.DataFrame(Y_pred, columns=columns_new)

# %%
import plotly.plotly as py
import plotly.graph_objs as go

# Create random data with numpy
import numpy as np

N = 100


# Create traces
trace0 = go.Scatter(
    x = X_test.values,
    y = Y_test.values,
    mode = 'markers',
    name = 'test values'
)
trace1 = go.Scatter(
    x = X_test.values, y = Y_pred,
    mode = 'markers',
    name = 'predicted values'
)


data = [trace0, trace1]
py.iplot(data, filename='scatter-mode')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~sach1990/4.embed" height="525px" width="100%"></iframe>

# %%
df = pd.read_csv('DayAvgSearchNotNormalizedReduced.csv')
df.head()
df = df.round()
df
data = df.iloc[:, [6 ,5]]

X = data.iloc[:, :-1]
Y = data.iloc[:, 1]
data.head()
diff_df = data.diff()
import plotly.graph_objs as go
from plotly.plotly import iplot

trace1 = go.Histogram(
    x=diff_df['Close'],
    opacity=0.75,
    name = "Close Values",
    marker=dict(color='rgba(171, 50, 96, 0.6)'))
trace2 = go.Histogram(
     x=diff_df['Close'],
    opacity=0.75,
    name = "Close Values",
    marker=dict(color='rgba(12, 50, 196, 0.6)'))

data = [trace1, trace2]
layout = go.Layout(barmode='overlay',
                   title=' students-staff ratio in 2011 and 2012',
                   xaxis=dict(title='students-staff ratio'),
                   yaxis=dict( title='Count'),
)
fig = go.Figure(data=data, layout=layout)
iplot(fig)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~sach1990/28.embed" height="525px" width="100%"></iframe>

# %%
X.head()
# Out:
#    TotalSearch
# 0      96867.0
# 1     111325.0
# 2     122892.0
# 3     114217.0
# 4     108434.0

# %%
Y.head()
# Out:
# 0    2518.0
# 1    2373.0
# 2    2338.0
# 3    2399.0
# 4    2358.0
# Name: Close, dtype: float64

# %%
diff_df
# Out:
#      TotalSearch  Close
# 0            NaN    NaN
# 1        14458.0 -145.0
# 2        11567.0  -35.0
# 3        -8675.0   61.0
# 4        -5783.0  -41.0
# 5         1446.0 -125.0
# 6        13012.0 -234.0
# 7        21686.0  -69.0
# 8       -10120.0  298.0
# 9            0.0   91.0
# 10      -14458.0  -46.0
# 11       14458.0  545.0
# 12        2891.0 -150.0
# 13      -20241.0  142.0
# 14        5784.0  -80.0
# 15       -4338.0   25.0
# 16        7229.0 -179.0
# 17       -2891.0  -47.0
# 18       -7229.0  143.0
# 19       14457.0  137.0
# 20      -21686.0  -83.0
# 21        1446.0   31.0
# 22       27469.0  118.0
# 23      126481.0 -157.0
# 24      -25532.0   -7.0
# 25      -73759.0   94.0
# 26      -17021.0   91.0
# 27       45390.0  357.0
# 28      -28369.0  -39.0
# 29       19858.0  165.0
# ..           ...    ...
# 299          0.0  -43.0
# 300      -7862.0  157.0
# 301      -3931.0 -203.0
# 302      13759.0 -282.0
# 303      -1966.0 -138.0
# 304     -13759.0   90.0
# ...

# %%
# prepare data
df = pd.read_csv('DayAvgSearchNotNormalizedReduced.csv')
df.head()
df = df.round()





df
data = df.iloc[:, [6 ,5]]

X = data.iloc[:, :-1]
Y = data.iloc[:, 1]



x = data[['Close']].values.astype(float)
x_scaled = min_max_scaler.fit_transform(x)
data_normalized = pd.DataFrame(x_scaled)
data['Close'] = data_normalized[0]

x = data[['TotalSearch']].values.astype(float)
x_scaled = min_max_scaler.fit_transform(x)
data_normalized = pd.DataFrame(x_scaled)
data['TotalSearch'] = data_normalized[0]

data.head()
diff_df = data.diff()
diff_df.head()
# Out:
#    TotalSearch     Close
# 0          NaN       NaN
# 1     0.005798 -0.008254
# 2     0.004638 -0.001992
# 3    -0.003479  0.003472
# 4    -0.002319 -0.002334

# %%
# prepare data
import plotly.graph_objs as go
from plotly.plotly import iplot

trace1 = go.Histogram(
    x=diff_df['TotalSearch'],
    opacity=0.75,
    name = "TotalSearch Values",
    marker=dict(color='rgba(171, 50, 96, 0.6)'))
trace2 = go.Histogram(
     x=diff_df['TotalSearch'],
    opacity=0.75,
    name = "TotalSearch Values",
    marker=dict(color='rgba(12, 50, 196, 0.6)'))

data = [trace1, trace2]
layout = go.Layout(barmode='overlay',
                   title=' students-staff ratio in 2011 and 2012',
                   xaxis=dict(title='students-staff ratio'),
                   yaxis=dict( title='Count'),
)
fig = go.Figure(data=data, layout=layout)
iplot(fig)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~sach1990/30.embed" height="525px" width="100%"></iframe>

# %%
diff_df.corr()
# Out:
#              TotalSearch     Close
# TotalSearch     1.000000  0.025299
# Close           0.025299  1.000000

# %%
import plotly.plotly as py
import plotly.graph_objs as go

# Create random data with numpy
import numpy as np

N = 100



trace1 = go.Scatter(
    x = diff_df['TotalSearch'].values, y = diff_df['Close'].values,
    mode = 'markers',
    name = 'predicted values'
)


data = [ trace1]
py.iplot(data, filename='scatter-mode')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~sach1990/4.embed" height="525px" width="100%"></iframe>
